# %% [markdown]
# # Pascal VOC 2007 EDA
#
# Use this notebook to inspect class presence, sample masks, subset tags, and split balance before training.

# %%
from pathlib import Path

import pandas as pd
from torchvision.datasets import VOCSegmentation

data_root = Path('/path/to/VOCtrainval_06-Nov-2007')
metadata_dir = Path('../artifacts/dataset')
train_df = pd.read_csv(metadata_dir / 'train_metadata.csv')
val_df = pd.read_csv(metadata_dir / 'val_metadata.csv')
train_df.head()

# %%
train_df[['person_present', 'small_object', 'crowded_scene', 'high_boundary_complexity']].mean()
